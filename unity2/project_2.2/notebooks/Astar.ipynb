# %%
# !pip install osmnx
# Out:
# Requirement already satisfied: osmnx in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (2.0.6)
# Requirement already satisfied: geopandas>=1.0.1 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from osmnx) (1.1.1)
# Requirement already satisfied: networkx>=2.5 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from osmnx) (3.5)
# Requirement already satisfied: numpy>=1.22 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from osmnx) (2.3.4)
# Requirement already satisfied: pandas>=1.4 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from osmnx) (2.3.3)
# Requirement already satisfied: requests>=2.27 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from osmnx) (2.32.5)
# Requirement already satisfied: shapely>=2.0 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from geopandas>=1.0.1->osmnx) (0.11.1)
# Requirement already satisfied: packaging in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from geopandas>=1.0.1->osmnx) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from requests>=2.27->osmnx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from requests>=2.27->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from requests>=2.27->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from requests>=2.27->osmnx) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /home/eduardo/Documentos/dca3702-aed2/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)

# %% [markdown]
# # A* Search in Urban Road Networks using OSMnx and NetworkX

# %%
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# Ensure plots are shown inline in notebooks
# %matplotlib inline

# %%
ox.__version__
# Out:
# '2.0.6'

# %%
nx.__version__
# Out:
# '3.5'

# %%
# Define a location (city, region or place name)
place = "Natal, Rio Grande do Norte, Brazil"

# Download the street network for driving
print("Downloading and creating the graph from OSM...")
G = ox.graph_from_place(place, network_type='drive')
# Out:
# Downloading and creating the graph from OSM...

# %%
type(G)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
# impute speed on all edges missing data
G = ox.routing.add_edge_speeds(G)

# calculate travel time (seconds) for all edges
G = ox.routing.add_edge_travel_times(G)

# %%
all_nodes = list(G.nodes(data=True))
all_nodes[:3]
# Out:
# [(243207469, {'y': -5.8314996, 'x': -35.1831317, 'street_count': 3}),
#  (243207479, {'y': -5.823197, 'x': -35.1833698, 'street_count': 3}),
#  (243207483, {'y': -5.8169275, 'x': -35.183197, 'street_count': 3})]

# %%
all_edges = list(G.edges(data=True))
all_edges[1]
# Out:
# (243207479,
#  7051202993,
#  {'osmid': 41129587,
#   'highway': 'primary',
#   'lanes': '2',
#   'maxspeed': '70',
#   'name': 'Avenida Senador Dinarte de Medeiros Mariz',
#   'oneway': True,
#   'ref': 'RN-301',
#   'reversed': False,
#   'length': np.float64(7.416712084339956),
#   'speed_kph': 70.0,
#   'travel_time': 0.3814309071946263})

# %%
# Define Source and Target

# Select arbitrary coordinates in the region (longitude, latitude)
src_point = (-35.1998821, -5.8428893)
dst_point = (-35.268811, -5.719613)

# Get the nearest nodes on the graph for these coordinates
print("Finding nearest graph nodes for origin and destination...")
src_node = ox.distance.nearest_nodes(G, src_point[0], src_point[1])
dst_node = ox.distance.nearest_nodes(G, dst_point[0], dst_point[1])
# Out:
# Finding nearest graph nodes for origin and destination...

# %%
# Extract node coordinates for plotting
src_x = G.nodes[src_node]['x']
src_y = G.nodes[src_node]['y']

dst_x = G.nodes[dst_node]['x']
dst_y = G.nodes[dst_node]['y']

# Plot the street network
print("Plotting the street network...")
fig, ax = ox.plot_graph(G, node_size=0, edge_linewidth=0.5, show=False, close=False)

# Plot the source point
ax.scatter(src_x, src_y, c='green', s=100, label='Source', zorder=5)

# Plot the destination point
ax.scatter(dst_x, dst_y, c='red', s=100, label='Destination', zorder=5)

# Add a legend to distinguish source and destination
ax.legend(loc='upper right')

# Display the plot
plt.show()
# Out:
# Plotting the street network...

# %% [markdown]
# ## A-star

# %% [markdown]
# ### Heuristic Euclidean

# %%
#%%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Running A* pathfinding algorithm by length..."
path_astar_length = nx.astar_path(
    G,
    src_node,
    dst_node,
    heuristic=lambda u, v: ox.distance.euclidean(
        G.nodes[u]['y'], G.nodes[u]['x'],
        G.nodes[v]['y'], G.nodes[v]['x']
    ),
    weight='length'
)

# %%
path_astar_length
# Out:
# [784697934,
#  501034060,
#  784697922,
#  784697937,
#  501825771,
#  500986659,
#  784697943,
#  784697954,
#  5467425830,
#  500968864,
#  506037044,
#  8636756106,
#  502539383,
#  560206857,
#  500968850,
#  7244035031,
#  500968851,
#  4727711401,
#  503792732,
#  4920577284,
#  501087579,
#  7189299453,
#  5368573911,
#  501152643,
#  501152645,
#  3003902433,
#  502752709,
#  502752711,
#  505487023,
#  505505758,
#  505506005,
#  505506202,
#  502752712,
#  583261757,
#  5272538953,
#  506570753,
#  7259825418,
#  7259825432,
#  7259825429,
#  7259825433,
#  7259825427,
#  7259825408,
#  503764948,
#  503759715,
#  506569654,
#  506569695,
#  506567372,
#  8064043013,
#  8622065248,
#  8064043001,
#  8064043017,
#  8064042999,
#  503769198,
#  503769209,
#  503755154,
#  503440708,
#  530771359,
#  1826924487,
#  1826924479,
#  1826924476,
#  1826924475,
#  1826924474,
#  1826924473,
#  1826924472,
#  529775368,
#  535254542,
#  529775372,
#  529775373,
#  529775374,
#  529775375,
#  1121742821,
#  529775378,
#  529775389,
#  1121742816,
#  5264901350,
#  5264901352,
#  5264901351,
#  3801130614,
#  535254153,
#  535254157,
#  535254129,
#  535254131,
#  526581787,
#  1437159038,
#  526577392,
#  526577393,
#  526577397,
#  9822301273,
#  526577325,
#  1826924284,
#  1826924280,
#  12600493827,
#  526569519,
#  7229166040,
#  12600547405,
#  1826964248,
#  1826964246,
#  12296035938,
#  502853901,
#  530763368,
#  502853903,
#  12949866837,
#  11025804797,
#  6415220871,
#  582091628,
#  7262628663,
#  502851375,
#  1877011486,
#  1877011462,
#  1877011339,
#  502851380,
#  523913605,
#  523913615,
#  6977211411,
#  7011742854,
#  7262583245,
#  523913676,
#  523913713,
#  535407064,
#  2154224443,
#  503486249,
#  7012558443,
#  7262481397,
#  582071825,
#  3800831217,
#  535427882,
#  582071821,
#  582071817,
#  582071816,
#  582071815,
#  582091723,
#  582071843,
#  582091716,
#  582091713,
#  582091712,
#  582091721,
#  503493085,
#  535427476,
#  535427717,
#  535427505,
#  8635760077,
#  503493080,
#  3800831205,
#  8635771717,
#  503493076,
#  542878204,
#  1876974393,
#  8635769814,
#  503493069,
#  582072302,
#  577609808,
#  4555710572,
#  503493062,
#  542878211,
#  7161914386,
#  577609818,
#  582092065,
#  582092063,
#  582092062,
#  3800898813,
#  582092058,
#  582072417,
#  582072419,
#  6120416096,
#  582072276,
#  582072277,
#  3800898874,
#  7059279310,
#  544491522,
#  523926847,
#  544491528,
#  8645120328,
#  535469204,
#  544335248,
#  7062746820,
#  544069320,
#  1826803289,
#  542883824,
#  544069310,
#  544069307,
#  1938123706,
#  544069326,
#  544069328,
#  3800882752,
#  535468891,
#  544069339,
#  544069351,
#  544069357,
#  535468596,
#  544069370,
#  3800882815,
#  544069415,
#  7042916082,
#  544069451,
#  6117494897,
#  3800882808,
#  8926494662,
#  8926494656,
#  5624856508,
#  5624856503,
#  5624856501,
#  5624856500,
#  544512515,
#  3800882789,
#  544512523,
#  3800882828,
#  7042977539,
#  3800882822,
#  3800882781,
#  3800882777,
#  544512538,
#  7042916035,
#  7042916036,
#  7042916037,
#  3800882829]

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Running A* pathfinding algorithm by travel time...
path_astar_time = nx.astar_path(
    G,
    src_node,
    dst_node,
    heuristic=lambda u, v: ox.distance.euclidean(
        G.nodes[u]['y'], G.nodes[u]['x'],
        G.nodes[v]['y'], G.nodes[v]['x']
    ),
    weight='travel_time'
)

# %%
path_astar_time
# Out:
# [784697934,
#  501034060,
#  784697922,
#  784697937,
#  501825771,
#  500986659,
#  784697943,
#  784697954,
#  5467425830,
#  500968864,
#  506037044,
#  8636756106,
#  502539383,
#  560206857,
#  500968850,
#  7244035031,
#  500968851,
#  4727711401,
#  503792732,
#  4920577284,
#  501087579,
#  502848536,
#  502723701,
#  8629676301,
#  526589278,
#  503787928,
#  7185738863,
#  504799394,
#  504801604,
#  504801607,
#  560213464,
#  560213463,
#  504799479,
#  504800093,
#  596783225,
#  503426482,
#  504801691,
#  504801692,
#  504799324,
#  503422520,
#  503422528,
#  504801845,
#  504801829,
#  504801823,
#  504801822,
#  501969363,
#  501969159,
#  501969167,
#  501969177,
#  501969183,
#  501969191,
#  501969200,
#  505561924,
#  501969208,
#  5301551599,
#  505486459,
#  505486469,
#  529723183,
#  529723190,
#  529723165,
#  501969217,
#  529723225,
#  6429460352,
#  529723232,
#  3801070728,
#  529723179,
#  529723215,
#  527200273,
#  3801070740,
#  535254735,
#  535254939,
#  5264233337,
#  503755115,
#  526577606,
#  534480616,
#  534480618,
#  535255037,
#  1121743147,
#  6412317121,
#  1827063254,
#  530768230,
#  1827029919,
#  502853880,
#  501969246,
#  526577546,
#  530761898,
#  530761927,
#  530761958,
#  502853922,
#  502853923,
#  530763353,
#  5920567636,
#  7224468163,
#  530763398,
#  12296035938,
#  502853901,
#  530763368,
#  502853903,
#  12949866837,
#  11025804797,
#  6415220871,
#  582091628,
#  7262628663,
#  502851375,
#  1877011348,
#  582091610,
#  6530743888,
#  8633444386,
#  582091326,
#  582091316,
#  582071630,
#  582071702,
#  535427677,
#  6993896350,
#  582071694,
#  582071696,
#  6410695188,
#  503498582,
#  582071686,
#  7048601638,
#  8633556921,
#  7050750559,
#  6993896355,
#  582071664,
#  582091374,
#  582091375,
#  7188268342,
#  6412820810,
#  577609709,
#  6140901562,
#  6140901575,
#  6140901569,
#  7048166626,
#  577609723,
#  1887626028,
#  1887626010,
#  1887625987,
#  3801034094,
#  12088325470,
#  582092186,
#  3801034081,
#  2118687967,
#  7042887001,
#  2118687966,
#  7042824185,
#  2068653949,
#  2068640835,
#  4681461297,
#  544512551,
#  6117561543,
#  7042916061,
#  3800882829]

# %% [markdown]
# ### Heuristic Great Circle

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Running A* pathfinding algorithm by length..."
path_astar_length = nx.astar_path(
    G,
    src_node,
    dst_node,
    heuristic=lambda u, v: ox.distance.great_circle(
        G.nodes[u]['y'], G.nodes[u]['x'],
        G.nodes[v]['y'], G.nodes[v]['x']
    ),
    weight='length'
)
# Out:
# 155 ms ± 624 μs per loop (mean ± std. dev. of 5 runs, 100 loops each)

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Running A* pathfinding algorithm by travel time...
path_astar_time = nx.astar_path(
    G,
    src_node,
    dst_node,
    heuristic=lambda u, v: ox.distance.great_circle(
        G.nodes[u]['y'], G.nodes[u]['x'],
        G.nodes[v]['y'], G.nodes[v]['x']
    ),
    weight='travel_time'
)
# Out:
# 12.2 ms ± 81 μs per loop (mean ± std. dev. of 5 runs, 100 loops each)

# %% [markdown]
# ### Heuristic Manhattan

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Running A* pathfinding algorithm by length..."
path_astar_length = nx.astar_path(
    G,
    src_node,
    dst_node,
    heuristic = lambda u, v: abs(G.nodes[u]['x'] - G.nodes[v]['x']) + abs(G.nodes[u]['y'] - G.nodes[v]['y']),
    weight='length'
)
# Out:
# 107 ms ± 689 μs per loop (mean ± std. dev. of 5 runs, 100 loops each)

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Running A* pathfinding algorithm by travel time...
path_astar_time = nx.astar_path(
    G,
    src_node,
    dst_node,
    heuristic = lambda u, v: abs(G.nodes[u]['x'] - G.nodes[v]['x']) + abs(G.nodes[u]['y'] - G.nodes[v]['y']),
    weight='travel_time'
)
# Out:
# 104 ms ± 3.28 ms per loop (mean ± std. dev. of 5 runs, 100 loops each)

# %%
# compare the two routes
route1_length = int(sum(ox.routing.route_to_gdf(G, path_astar_length, weight="length")["length"]))
route2_length = int(sum(ox.routing.route_to_gdf(G, path_astar_time, weight="travel_time")["length"]))
route1_time = int(sum(ox.routing.route_to_gdf(G, path_astar_length, weight="length")["travel_time"]))
route2_time = int(sum(ox.routing.route_to_gdf(G, path_astar_time, weight="travel_time")["travel_time"]))
print("Route 1 (a-star length) is", route1_length, "meters and takes", route1_time, "seconds.")
print("Route 2 (a-star travel time) is", route2_length, "meters and takes", route2_time, "seconds.")
# Out:
# Route 1 (a-star length) is 19995 meters and takes 1646 seconds.
# Route 2 (a-star travel time) is 23853 meters and takes 1342 seconds.

# %% [markdown]
# ## Dijkstra

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Dijkstra for Comparison by Length
path_dijkstra_length = nx.shortest_path(
    G,
    source=src_node,
    target=dst_node,
    weight='length'
)

# %%
# %%timeit -n 100 -r 5
# -n: number of executions per run (loops)
# -r: number of runs (repetitions)

# Dijkstra for Comparison by travel time ---
path_dijkstra_time = nx.shortest_path(
    G,
    source=src_node,
    target=dst_node,
    weight='travel_time'
)

# %%
# compare the two routes
d_route1_length = int(sum(ox.routing.route_to_gdf(G, path_dijkstra_length, weight="length")["length"]))
d_route2_length = int(sum(ox.routing.route_to_gdf(G, path_dijkstra_time, weight="travel_time")["length"]))
d_route1_time = int(sum(ox.routing.route_to_gdf(G, path_dijkstra_length, weight="length")["travel_time"]))
d_route2_time = int(sum(ox.routing.route_to_gdf(G, path_dijkstra_time, weight="travel_time")["travel_time"]))
print("Route 1 (dijkstra length) is", d_route1_length, "meters and takes", d_route1_time, "seconds.")
print("Route 2 (dijkstra travel time) is", d_route2_length, "meters and takes", d_route2_time, "seconds.")
# Out:
# Route 1 (dijkstra length) is 19995 meters and takes 1646 seconds.
# Route 2 (dijkstra travel time) is 23853 meters and takes 1342 seconds.

# %% [markdown]
# ## Summarization

# %% [markdown]
# | Heuristic/Algorithm      | Weight          | Mean (ms) | Standard Deviation (ms) | Distance (m) | Travel Time (s) |
# |--------------------------|-----------------|-----------|------------------------|--------------|-----------------|
# | `euclidean`              | `length`        | 153.00    | 4.04                   | 21697         | 1885            |
# | `euclidean`              | `travel_time`   | 156.00    | 5.95                   | 23830          | 1541              |
# | `great_circle`           | `length`        | 229.00    | 3.77                   |21697        |1885             |
# | `great_circle`           | `travel_time`   | 19.80     | 3.72                   | 24539         | 1940           |
# | `manhattan` (approx abs) | `length`        | 146.00    | 1.03                   | 21697         | 1885             |
# | `manhattan` (approx abs) | `travel_time`   | 145.00    | 3.34                   | 23830          | 1541          |
# | `dijkstra`               | `length`        | 149.00    | 6.61                   | 21697          | 1885            |
# | `dijkstra`               | `travel_time`   | 135.00    | 4.31                   | 23830          | 1541           |

# %% [markdown]
# ## Visualization

# %%
print("Plotting the A* path...")
fig1, ax1 = ox.plot_graph_routes(G, routes=[path_astar_length, path_astar_time],
                                 route_colors=['r','y'],
                                 route_linewidth=6,
                                 node_size=0,
                                 show=False,
                                 close=False)

# Cria linhas fictícias para legenda
astar_length_line = mlines.Line2D([], [], color='r', label='A* (Length)')
astar_time_line = mlines.Line2D([], [], color='y', label='A* (Travel_Time)')

# Adiciona a legenda ao gráfico
ax1.legend(handles=[astar_length_line, astar_time_line], loc='upper right')

# Exibe o gráfico com a legenda
plt.show()
# Out:
# Plotting the A* path...

# %%
print("Plotting the Dijkstra path...")
fig2, ax2 = ox.plot_graph_routes(G, routes=[path_dijkstra_length, path_dijkstra_time],
                                 route_colors=['r','y'],
                                 route_linewidth=6,
                                 node_size=0,
                                 show=False,
                                 close=False)

# Cria linhas fictícias para legenda
dijkstra_length_line = mlines.Line2D([], [], color='r', label='Dijkstra (Length)')
dijkstra_time_line = mlines.Line2D([], [], color='y', label='Dijsktra (Time)')

# Adiciona a legenda ao gráfico
ax2.legend(handles=[dijkstra_length_line, dijkstra_time_line], loc='upper right')

# Exibe o gráfico com a legenda
plt.show()
# Out:
# Plotting the Dijkstra path...
